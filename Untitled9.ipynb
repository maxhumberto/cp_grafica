# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

vermelho = (0, 0, 255)
verde = (0, 255, 0 )
azul = (255, 0 ,0)

cv2.line(imagem, (0,0), (100, 200), verde)
cv2.line(imagem, (300, 200), (150, 150), vermelho, 5)

cv2.rectangle(imagem, (20, 20), (120, 120), azul, 20)
cv2.rectangle(imagem, (200, 50), (225, 125), verde, -1)

(x,y) = (imagem.shape[1] //2, imagem.shape[0] //2)
for raio in range(0, 175 ,15):
  cv2.circle(imagem, (x, y), raio, vermelho)

cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FDC25F9EEE0>
