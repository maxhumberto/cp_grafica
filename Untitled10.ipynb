# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

fonte = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(imagem, "kimi no name wa? " (15,65), fonte, 2,(255, 255, 255), 2, cv2.LINE_AA)

cv2_imshow(imagem)
# Out:
# <>:9: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:9: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <ipython-input-2-8b8b22a7abc1>:9: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   cv2.putText(imagem, "kimi no name wa? " (15,65), fonte, 2,(255, 255, 255), 2, cv2.LINE_AA)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-8b8b22a7abc1> in <module>
#       7 fonte = cv2.FONT_HERSHEY_SIMPLEX
#       8
# ----> 9 cv2.putText(imagem, "kimi no name wa? " (15,65), fonte, 2,(255, 255, 255), 2, cv2.LINE_AA)
#      10
#      11 cv2_imshow(imagem)
#
# TypeError: 'str' object is not callable
