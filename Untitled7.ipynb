# %%
from google.colab import files


import cv2
import os

from google.colab.patches import cv2_imshow

imagem = cv2.imread("tiger.jpg")

imagem_pb = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
imagem_invertida = cv2.bitwise_not(imagem_pb)
imagem_blur = cv2.GaussianBlur(imagem_invertida, (qtde_filtro, qtde_filtro), 0)
cv2_imshow(imagem_blur)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-951868f768ec> in <module>
#      11 imagem_pb = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
#      12 imagem_invertida = cv2.bitwise_not(imagem_pb)
# ---> 13 imagem_blur = cv2.GaussianBlur(imagem_invertida, (qtde_filtro, qtde_filtro), 0)
#      14 cv2_imshow(imagem_blur)
#
# NameError: name 'qtde_filtro' is not defined
