# %%
from google.colab import files


import cv2
from google.colab.patches import cv2_imshow

imagem = cv2.imread("/content/one-piece-anime-1015-luffy-chapeu-postcover.jpg")

imagem[30:50, :] = (255, 0, 0)
imagem[:, 200:220] = (0, 255, 255)
imagem[150:300, 250:350] = (0, 255, 0)
imagem[300:400, 50:150] = (255, 255, 0)
imagem[250:350, 300:400] = (255, 255, 255)
imagem [70:100, 300:450] = (0, 0, 0)

cv2_imshow(imagem)
cv2.imwrite(" saida.jpg", imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F29F8086460>
# True
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F29F80F1CD0>
# True
